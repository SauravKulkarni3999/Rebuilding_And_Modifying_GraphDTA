# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Define the project root and data path
project_root = "/content/drive/MyDrive/Rebuilding_and_Modifying_GraphDTA"
data_path = f"{project_root}/data"

# %%
#Test parse and submit to NCBI Blast
from Bio import SeqIO
from Bio.Blast import NCBIWWW, NCBIXML
import time

#Load FASTA File from drive
fasta_path = f"{data_path}/davis_proteins.fasta"
records = list(SeqIO.parse(fasta_path, "fasta"))

#Select first 5 for testing
test_records = records[:5]

results = []

for record in test_records:
  print(f"Querying {record.id}...")
  try:
    result_handle = NCBIWWW.qblast("blastp", "swissprot", record.format("fasta"))
    blast_record = NCBIXML.read(result_handle)

    if blast_record.alignments:
      top_hit = blast_record.alignments[0].accession
      results.append({"Protein_ID": record.id, "UniProt_ID": top_hit})
    else:
      results.append({"Protein_ID": record.id, "UniProt_ID": None})

    time.sleep(2) #Respect NCBI rate limit

  except Exception as e:
    print(f"Error for {record.id}: {e}")
    results.append({"Protein_ID": record.id, "UniProt_ID": None})

#Takes almost 10 minutes for 5 proteins, not feasible for 433 sequences.
# Out:
# Querying Protein_0...
# Querying Protein_1...
# Querying Protein_3...
# Querying Protein_5...
# Querying Protein_7...

# %%
# !wget -O /content/uniprot_sprot.fasta.gz "https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz"
# !gunzip -f /content/uniprot_sprot.fasta.gz
# Out:
# --2025-05-17 02:42:21--  https://ftp.uniprot.org/pub/databases/uniprot/current_release/knowledgebase/complete/uniprot_sprot.fasta.gz
# Resolving ftp.uniprot.org (ftp.uniprot.org)... 128.175.240.195
# Connecting to ftp.uniprot.org (ftp.uniprot.org)|128.175.240.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92986586 (89M) [application/x-gzip]
# Saving to: ‘/content/uniprot_sprot.fasta.gz’
#
# /content/uniprot_sp 100%[===================>]  88.68M  84.8MB/s    in 1.0s
#
# 2025-05-17 02:42:22 (84.8 MB/s) - ‘/content/uniprot_sprot.fasta.gz’ saved [92986586/92986586]

# %%
from Bio import SeqIO
import pandas as pd

# Load Davis sequences
davis_records = list(SeqIO.parse("/content/davis_proteins.fasta", "fasta"))
davis_map = {str(record.seq): record.id for record in davis_records}

# Load UniProt (Swiss-Prot) FASTA
uniprot_records = list(SeqIO.parse("/content/uniprot_sprot.fasta", "fasta"))

matches = []
for record in uniprot_records:
    seq = str(record.seq)
    if seq in davis_map:
        matches.append({
            "Protein_ID": davis_map[seq],
            "UniProt_ID": record.id.split("|")[1] if "|" in record.id else record.id
        })

# Save mapping
df = pd.DataFrame(matches)
output_path = "/content/drive/MyDrive/Rebuilding_and_Modifying_GraphDTA/data/uniprot_mapping.csv"
df.to_csv(output_path, index=False)

print(f"✅ Saved {len(df)} matches to: {output_path}")
# Out:
# ✅ Saved 267 matches to: /content/drive/MyDrive/Rebuilding_and_Modifying_GraphDTA/data/uniprot_mapping.csv

# %%
import pandas as pd
import os
import requests

# Load UniProt mapping
df = pd.read_csv("/content/drive/MyDrive/Rebuilding_and_Modifying_GraphDTA/data/uniprot_mapping.csv")

# Set output directory for PDB files
output_dir = "/content/drive/MyDrive/Rebuilding_and_Modifying_GraphDTA/data/davis_alphafold_structures"
os.makedirs(output_dir, exist_ok=True)

# Download AlphaFold .pdb files
for _, row in df.iterrows():
    protein_id = row["Protein_ID"]
    uniprot_id = row["UniProt_ID"]
    url = f"https://alphafold.ebi.ac.uk/files/AF-{uniprot_id}-F1-model_v4.pdb"
    save_path = os.path.join(output_dir, f"{protein_id}.pdb")

    if not os.path.exists(save_path):
        try:
            response = requests.get(url)
            if response.status_code == 200:
                with open(save_path, "wb") as f:
                    f.write(response.content)
                print(f"✅ Downloaded: {protein_id} → {uniprot_id}")
            else:
                print(f"❌ Not found: {uniprot_id} (status: {response.status_code})")
        except Exception as e:
            print(f"❌ Error for {uniprot_id}: {e}")
# Out:
# ✅ Downloaded: Protein_29 → P54646
# ✅ Downloaded: Protein_15 → P00519
# ✅ Downloaded: Protein_18 → P36896
# ✅ Downloaded: Protein_17 → Q04771
# ✅ Downloaded: Protein_24 → P31749
# ✅ Downloaded: Protein_25 → P31751
# ✅ Downloaded: Protein_26 → Q9Y243
# ✅ Downloaded: Protein_27 → Q9UM73
# ✅ Downloaded: Protein_30 → Q8NFD2
# ✅ Downloaded: Protein_34 → O14965
# ✅ Downloaded: Protein_19 → P27037
# ✅ Downloaded: Protein_20 → Q13705
# ✅ Downloaded: Protein_39 → P51451
# ✅ Downloaded: Protein_42 → Q13873
# ✅ Downloaded: Protein_40 → P36894
# ✅ Downloaded: Protein_41 → O00238
# ✅ Downloaded: Protein_43 → P51813
# ✅ Downloaded: Protein_44 → P15056
# ✅ Downloaded: Protein_47 → Q8TDC3
# ✅ Downloaded: Protein_49 → Q06187
# ✅ Downloaded: Protein_63 → Q14004
# ✅ Downloaded: Protein_294 → Q00536
# ✅ Downloaded: Protein_296 → Q07002
# ✅ Downloaded: Protein_64 → Q9BWU1
# ✅ Downloaded: Protein_301 → P61075
# ✅ Downloaded: Protein_65 → P24941
# ✅ Downloaded: Protein_66 → Q00526
# ✅ Downloaded: Protein_69 → Q00535
# ✅ Downloaded: Protein_70 → P50613
# ✅ Downloaded: Protein_71 → P49336
# ✅ Downloaded: Protein_72 → P50750
# ✅ Downloaded: Protein_74 → Q92772
# ✅ Downloaded: Protein_75 → Q8IVW4
# ✅ Downloaded: Protein_300 → P62344
# ✅ Downloaded: Protein_77 → O14757
# ✅ Downloaded: Protein_182 → Q9UPZ9
# ✅ Downloaded: Protein_82 → P49761
# ✅ Downloaded: Protein_83 → Q9HAZ1
# ✅ Downloaded: Protein_22 → Q8NI60
# ✅ Downloaded: Protein_23 → Q96D53
# ✅ Downloaded: Protein_84 → P07333
# ✅ Downloaded: Protein_93 → P68399
# ✅ Downloaded: Protein_94 → P19784
# ✅ Downloaded: Protein_85 → P41240
# ✅ Downloaded: Protein_79 → O14578
# ✅ Downloaded: Protein_96 → P53355
# ✅ Downloaded: Protein_97 → Q9UIK4
# ✅ Downloaded: Protein_98 → O43293
# ✅ Downloaded: Protein_101 → Q9C098
# ✅ Downloaded: Protein_105 → Q09013
# ✅ Downloaded: Protein_110 → Q9Y463
# ✅ Downloaded: Protein_124 → Q9BQI3
# ✅ Downloaded: Protein_349 → P19525
# ✅ Downloaded: Protein_112 → P00533
# ✅ Downloaded: Protein_126 → P29317
# ✅ Downloaded: Protein_127 → P29320
# ✅ Downloaded: Protein_128 → P54764
# ✅ Downloaded: Protein_131 → Q15375
# ✅ Downloaded: Protein_132 → P29322
# ✅ Downloaded: Protein_133 → P54762
# ✅ Downloaded: Protein_135 → P54753
# ✅ Downloaded: Protein_136 → P54760
# ✅ Downloaded: Protein_137 → O15197
# ✅ Downloaded: Protein_139 → P21860
# ✅ Downloaded: Protein_147 → O75460
# ✅ Downloaded: Protein_148 → Q05397
# ✅ Downloaded: Protein_149 → P16591
# ✅ Downloaded: Protein_150 → P07332
# ✅ Downloaded: Protein_153 → P22607
# ✅ Downloaded: Protein_156 → P09769
# ✅ Downloaded: Protein_158 → P36888
# ✅ Downloaded: Protein_166 → P42685
# ✅ Downloaded: Protein_168 → O14976
# ✅ Downloaded: Protein_170 → Q15835
# ✅ Downloaded: Protein_171 → P32298
# ✅ Downloaded: Protein_172 → Q8WTQ7
# ✅ Downloaded: Protein_173 → P49840
# ✅ Downloaded: Protein_175 → P08631
# ✅ Downloaded: Protein_177 → Q9H2X6
# ✅ Downloaded: Protein_178 → Q9H422
# ✅ Downloaded: Protein_179 → Q8NE63
# ✅ Downloaded: Protein_181 → P57058
# ✅ Downloaded: Protein_183 → P08069
# ✅ Downloaded: Protein_184 → O15111
# ✅ Downloaded: Protein_185 → O14920
# ✅ Downloaded: Protein_186 → Q14164
# ✅ Downloaded: Protein_188 → P14616
# ✅ Downloaded: Protein_187 → P06213
# ✅ Downloaded: Protein_189 → P51617
# ✅ Downloaded: Protein_191 → Q9NWZ3
# ✅ Downloaded: Protein_192 → Q08881
# ✅ Downloaded: Protein_329 → P17612
# ✅ Downloaded: Protein_330 → P22694
# ✅ Downloaded: Protein_86 → P48729
# ✅ Downloaded: Protein_89 → P49674
# ✅ Downloaded: Protein_90 → Q9HCP0
# ✅ Downloaded: Protein_92 → Q9Y6M4
# ✅ Downloaded: Protein_50 → Q14012
# ✅ Downloaded: Protein_52 → Q96NX5
# ✅ Downloaded: Protein_53 → Q9UQM7
# ✅ Downloaded: Protein_54 → Q13554
# ✅ Downloaded: Protein_57 → Q16566
# ✅ Downloaded: Protein_348 → Q13237
# ✅ Downloaded: Protein_200 → P10721
# ✅ Downloaded: Protein_58 → Q8N5S9
# ✅ Downloaded: Protein_59 → Q96RR4
# ✅ Downloaded: Protein_344 → Q15139
# ✅ Downloaded: Protein_345 → Q9BZL6
# ✅ Downloaded: Protein_346 → O94806
# ✅ Downloaded: Protein_339 → Q05655
# ✅ Downloaded: Protein_340 → Q02156
# ✅ Downloaded: Protein_341 → P24723
# ✅ Downloaded: Protein_343 → Q04759
# ✅ Downloaded: Protein_380 → P23443
# ✅ Downloaded: Protein_399 → P43405
# ✅ Downloaded: Protein_208 → O95835
# ✅ Downloaded: Protein_210 → P06239
# ✅ Downloaded: Protein_211 → P53667
# ✅ Downloaded: Protein_212 → P53671
# ✅ Downloaded: Protein_218 → P07948
# ✅ Downloaded: Protein_254 → Q02779
# ✅ Downloaded: Protein_255 → Q16584
# ✅ Downloaded: Protein_219 → O43283
# ✅ Downloaded: Protein_439 → Q56UN5
# ✅ Downloaded: Protein_221 → Q13233
# ✅ Downloaded: Protein_223 → Q9Y2U5
# ✅ Downloaded: Protein_224 → Q99759
# ✅ Downloaded: Protein_32 → Q99683
# ✅ Downloaded: Protein_33 → O95382
# ✅ Downloaded: Protein_400 → O43318
# ✅ Downloaded: Protein_226 → Q12851
# ✅ Downloaded: Protein_227 → Q8IVH8
# ✅ Downloaded: Protein_229 → Q9Y4K4
# ✅ Downloaded: Protein_220 → P20794
# ✅ Downloaded: Protein_230 → P49137
# ✅ Downloaded: Protein_232 → Q9P0L2
# ✅ Downloaded: Protein_236 → Q9Y2H9
# ✅ Downloaded: Protein_243 → Q14680
# ✅ Downloaded: Protein_245 → P08581
# ✅ Downloaded: Protein_142 → P28482
# ✅ Downloaded: Protein_141 → P27361
# ✅ Downloaded: Protein_144 → P31152
# ✅ Downloaded: Protein_143 → Q16659
# ✅ Downloaded: Protein_145 → Q13164
# ✅ Downloaded: Protein_197 → Q91Y86
# ✅ Downloaded: Protein_285 → Q15759
# ✅ Downloaded: Protein_286 → O15264
# ✅ Downloaded: Protein_284 → Q16539
# ✅ Downloaded: Protein_146 → Q8TD08
# ✅ Downloaded: Protein_237 → Q02750
# ✅ Downloaded: Protein_238 → P36507
# ✅ Downloaded: Protein_240 → P45985
# ✅ Downloaded: Protein_241 → Q13163
# ✅ Downloaded: Protein_242 → P52564
# ✅ Downloaded: Protein_249 → O14733
# ✅ Downloaded: Protein_257 → Q9Y5S2
# ✅ Downloaded: Protein_106 → Q6DT37
# ✅ Downloaded: Protein_263 → P42345
# ✅ Downloaded: Protein_264 → O15146
# ✅ Downloaded: Protein_266 → Q9H1R3
# ✅ Downloaded: Protein_252 → Q32MK0
# ✅ Downloaded: Protein_268 → Q8NEV4
# ✅ Downloaded: Protein_272 → Q96PY6
# ✅ Downloaded: Protein_274 → P51955
# ✅ Downloaded: Protein_275 → P51956
# ✅ Downloaded: Protein_276 → P51957
# ✅ Downloaded: Protein_277 → Q6P3R8
# ✅ Downloaded: Protein_278 → Q9HC98
# ✅ Downloaded: Protein_279 → Q8TDX7
# ✅ Downloaded: Protein_281 → Q8IY84
# ✅ Downloaded: Protein_282 → Q9UBE8
# ✅ Downloaded: Protein_31 → O60285
# ✅ Downloaded: Protein_387 → Q9H093
# ✅ Downloaded: Protein_283 → O95747
# ✅ Downloaded: Protein_288 → Q13153
# ✅ Downloaded: Protein_289 → Q13177
# ✅ Downloaded: Protein_293 → Q9P286
# ✅ Downloaded: Protein_292 → Q9NQU5
# ✅ Downloaded: Protein_299 → O15530
# ✅ Downloaded: Protein_297 → P16234
# ✅ Downloaded: Protein_298 → P09619
# ✅ Downloaded: Protein_304 → Q16816
# ✅ Downloaded: Protein_305 → P15735
# ✅ Downloaded: Protein_327 → P78356
# ✅ Downloaded: Protein_325 → Q99755
# ✅ Downloaded: Protein_326 → O60331
# ✅ Downloaded: Protein_322 → P11309
# ✅ Downloaded: Protein_323 → Q9P1W9
# ✅ Downloaded: Protein_308 → P42336
# ✅ Downloaded: Protein_318 → P42338
# ✅ Downloaded: Protein_320 → P48736
# ✅ Downloaded: Protein_333 → Q16513
# ✅ Downloaded: Protein_334 → P0A5S5
# ✅ Downloaded: Protein_335 → P53350
# ✅ Downloaded: Protein_336 → Q9NYY3
# ✅ Downloaded: Protein_337 → Q9H4B4
# ✅ Downloaded: Protein_350 → P51817
# ✅ Downloaded: Protein_351 → Q13523
# ✅ Downloaded: Protein_46 → Q13882
# ✅ Downloaded: Protein_354 → P04049
# ✅ Downloaded: Protein_359 → Q9BRS2
# ✅ Downloaded: Protein_361 → O14730
# ✅ Downloaded: Protein_362 → Q13546
# ✅ Downloaded: Protein_363 → O43353
# ✅ Downloaded: Protein_366 → Q13464
# ✅ Downloaded: Protein_367 → O75116
# ✅ Downloaded: Protein_259 → Q04912
# ✅ Downloaded: Protein_368 → P08922
# ✅ Downloaded: Protein_381 → Q52WX2
# ✅ Downloaded: Protein_382 → P0C264
# ✅ Downloaded: Protein_383 → Q96BR1
# ✅ Downloaded: Protein_384 → P57059
# ✅ Downloaded: Protein_385 → Q9H0K1
# ✅ Downloaded: Protein_386 → Q9H2G2
# ✅ Downloaded: Protein_388 → Q9NRH2
# ✅ Downloaded: Protein_389 → P12931
# ✅ Downloaded: Protein_390 → Q9H3Y6
# ✅ Downloaded: Protein_391 → Q96SB4
# ✅ Downloaded: Protein_393 → Q9UPE1
# ✅ Downloaded: Protein_108 → O94768
# ✅ Downloaded: Protein_434 → Q8WU08
# ✅ Downloaded: Protein_435 → Q9NY57
# ✅ Downloaded: Protein_436 → Q86UX6
# ✅ Downloaded: Protein_271 → Q9Y2H1
# ✅ Downloaded: Protein_214 → O94804
# ✅ Downloaded: Protein_213 → Q15831
# ✅ Downloaded: Protein_261 → Q9Y6E0
# ✅ Downloaded: Protein_438 → O00506
# ✅ Downloaded: Protein_262 → Q9P289
# ✅ Downloaded: Protein_395 → Q9BYT3
# ✅ Downloaded: Protein_270 → Q15208
# ✅ Downloaded: Protein_398 → Q9UEW8
# ✅ Downloaded: Protein_258 → Q13043
# ✅ Downloaded: Protein_401 → Q7L7X3
# ✅ Downloaded: Protein_402 → Q9UL54
# ✅ Downloaded: Protein_404 → Q9UHD2
# ✅ Downloaded: Protein_406 → Q15569
# ✅ Downloaded: Protein_407 → P36897
# ✅ Downloaded: Protein_408 → P37173
# ✅ Downloaded: Protein_409 → P35590
# ✅ Downloaded: Protein_411 → Q9UKI8
# ✅ Downloaded: Protein_416 → Q59H18
# ✅ Downloaded: Protein_413 → Q9UKE5
# ✅ Downloaded: Protein_420 → Q9BX84
# ✅ Downloaded: Protein_421 → Q9BXA7
# ✅ Downloaded: Protein_422 → P33981
# ✅ Downloaded: Protein_423 → P42681
# ✅ Downloaded: Protein_426 → Q06418
# ✅ Downloaded: Protein_429 → Q6PHR2
# ✅ Downloaded: Protein_157 → P17948
# ✅ Downloaded: Protein_430 → P35968
# ✅ Downloaded: Protein_431 → Q86Y07
# ✅ Downloaded: Protein_432 → P30291
# ✅ Downloaded: Protein_433 → P0C1S8
# ✅ Downloaded: Protein_437 → P07947
